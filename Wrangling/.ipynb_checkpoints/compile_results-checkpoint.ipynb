# %%
import pandas as pd
import re

# %%
def add_source(df, source):
    """Add columns indictating the lab the data came from"""
    dataframe = df.copy()
    dataframe['ana360'] = int(source == 'ana360')
    dataframe['psilabs'] = int(source == 'psilabs')
    dataframe['sclabs'] = int(source == 'sclabs')
    return dataframe

# %%
def drop_columns(df):
    """Drop columns other than name that do not have numeric values that can be averaged"""
    drops = ['Test Result UID', 'Receipt Time', 'Test Time', 'Provider']
    if 'Post Time' in df.columns:
        drops = drops + ['Post Time']
    return df.drop(columns=drops)

# %%
def conform_names(name):
    """Standardize names of strains across data sets"""
    
    # change any upper case letters to lower case
    name = name.lower()
    
    # strip out text enclosed in brackets, parantheses, or quotes
    brackets = r'[\[({<].*?[\])}>]'
    name = re.sub(brackets, '', name)
    
    # remove characters that are not letters, numbers, spaces, hyphens, or underscores
    drop = r'[^a-z0-9 _-]'
    name = re.sub(drop, '', name)
    
    # replace hyphens and underscores with spaces
    name = re.sub(r'[_-]', ' ', name)
    
    # split string on spaces and rejoin with hypens
    name = '-'.join(name.split())
    
    return name

# %%
def process_dataframe(dataframe, source):
    """Process dataframe and rename column"""
    dataframe = add_source(dataframe, source)
    dataframe = drop_columns(dataframe)
    dataframe['Sample Name'] = dataframe['Sample Name'].apply(conform_names)
    dataframe = dataframe.rename(columns={'Sample Name': 'strain'})
        
    return dataframe

# %% [markdown]
# ### Create dataframes and process them to a single dataframe

# %%
ana360 = pd.read_csv('./web_scrapers/analytical360/results.csv')
ana360 = process_dataframe(ana360, 'ana360')

# %%
psilabs = pd.read_csv('./web_scrapers/psilabs/results.csv')
psilabs = process_dataframe(psilabs, 'psilabs')

# %%
sclabs = pd.read_csv('./web_scrapers/sclabs/results.csv')
sclabs = process_dataframe(sclabs, 'sclabs')

# %%
ana360.head()
# Out:
#               strain Sample Type  cis-Nerolidol  trans-Nerolidol  \
# 0  bho-blackberry-22    Archived            NaN              NaN
# 1   bho-the-sour-bud    Archived            NaN              NaN
# 2    northern-lights    Archived            NaN              NaN
# 3     blueberry-kush    Archived            NaN              NaN
# 4         white-dawg    Archived            NaN              NaN
#
#    trans-Nerolidol 1  trans-Nerolidol 2  trans-Ocimene  3-Carene  Camphene  \
# 0                NaN                NaN            NaN       NaN       NaN
# 1                NaN                NaN            NaN       NaN       NaN
# 2                NaN                NaN            NaN       NaN       NaN
# 3                NaN                NaN            NaN       NaN       NaN
# 4                NaN                NaN            NaN       NaN       NaN
#
#    Caryophyllene Oxide  ...  CBD  CBDV  CBDV-A  delta-9 CBG-A  delta-9 CBG  \
# 0                  NaN  ...  NaN   NaN     NaN           0.08          NaN
# 1                  NaN  ...  NaN   NaN     NaN           0.75         0.34
# 2                  NaN  ...  NaN   NaN     NaN           0.66         0.05
# 3                  NaN  ...  NaN   NaN     NaN           0.25         0.19
# 4                  NaN  ...  NaN   NaN     NaN           0.12         0.11
#
#    CBC  Moisture Content  ana360  psilabs  sclabs
# 0  NaN               NaN       1        0       0
# 1  NaN               NaN       1        0       0
# 2  NaN               NaN       1        0       0
# 3  NaN               NaN       1        0       0
# 4  NaN               NaN       1        0       0
#
# [5 rows x 45 columns]

# %%
psilabs.head()
# Out:
#                                strain  Sample Type  cis-Nerolidol  \
# 0  cbdees-whole-live-plant-distillate  Concentrate            NaN
# 1                   girl-scout-cookie  Concentrate            NaN
# 2                blueberry-haze-htfse  Concentrate            0.0
# 3             011518-02-straw-lem-sce  Concentrate            0.0
# 4             011518-02-straw-lem-sce  Concentrate            0.0
#
#    trans-Nerolidol  trans-Nerolidol 1  trans-Nerolidol 2  trans-Ocimene  \
# 0              NaN                0.0                0.0            NaN
# 1              NaN                0.0                0.0            NaN
# 2              0.0                NaN                NaN            NaN
# 3              0.0                NaN                NaN            NaN
# 4              0.0                NaN                NaN            NaN
#
#    3-Carene  Camphene  Caryophyllene Oxide  ...    CBD  CBDV  CBDV-A  \
# 0       0.0      0.00                  0.0  ...  68.65   NaN     NaN
# 1       0.0      0.05                  0.0  ...   0.05   NaN     NaN
# 2       0.0      0.19                  0.0  ...   0.01   NaN     NaN
# 3       0.0      0.13                  0.0  ...   0.01   NaN     NaN
# 4       0.0      0.13                  0.0  ...   0.01   NaN     NaN
#
#    delta-9 CBG-A  delta-9 CBG   CBC  Moisture Content  ana360  psilabs  sclabs
# 0            NaN         2.20  2.36               NaN       0        1       0
# 1            NaN         2.76  0.69               NaN       0        1       0
# 2           7.66         2.52  0.66               NaN       0        1       0
# 3           8.75         1.55  0.01               NaN       0        1       0
# 4           8.75         1.55  0.01               NaN       0        1       0
#
# [5 rows x 45 columns]

# %%
sclabs.head()
# Out:
#                strain             Sample Type  cis-Nerolidol  trans-Nerolidol  \
# 0          guava-kush       Flower, Inhalable            NaN              NaN
# 1  watermelon-rancher       Flower, Inhalable            NaN              NaN
# 2            pscr-634  Concentrate, Inhalable            NaN              NaN
# 3            stcr-638  Concentrate, Inhalable            NaN              NaN
# 4            pscr-639  Concentrate, Inhalable            NaN              NaN
#
#    trans-Nerolidol 1  trans-Nerolidol 2  trans-Ocimene  3-Carene  Camphene  \
# 0                NaN                NaN            NaN     0.000     0.019
# 1                NaN                NaN            NaN     0.036     0.005
# 2                NaN                NaN            NaN     0.000     0.000
# 3                NaN                NaN            NaN     0.000     0.000
# 4                NaN                NaN            NaN     0.000     0.035
#
#    Caryophyllene Oxide  ...  CBD  CBDV  CBDV-A  delta-9 CBG-A  delta-9 CBG  \
# 0                0.011  ...  0.0  0.00    0.02           0.39         0.09
# 1                0.000  ...  0.0  0.01    0.02           0.11         0.09
# 2                0.206  ...  0.0  0.00    0.00           1.32         0.12
# 3                0.000  ...  0.0  0.26    0.00           0.90         0.09
# 4                0.038  ...  0.0  0.00    0.00           0.97         0.38
#
#     CBC  Moisture Content  ana360  psilabs  sclabs
# 0  0.08               NaN       0        0       1
# 1  0.03               NaN       0        0       1
# 2  0.00               NaN       0        0       1
# 3  0.11               NaN       0        0       1
# 4  0.00               NaN       0        0       1
#
# [5 rows x 45 columns]
